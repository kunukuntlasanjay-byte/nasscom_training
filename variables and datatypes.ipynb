# %%
x=10
y=3.5
name="sanjay"
is_sum=True
print(type(x))
print(type(y))
print(type(name))
print(type(is_sum))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=15
b=4
print("addition :",a+b)
print("subtraction:",a-b)
print("multiplication:",a*b)
print("exponential power:",a**b)
print("division:",a/b)
print("floor division:",a//b)
print("modulo divison:", a%b)
# Out:
# addition : 19
# subtraction: 11
# multiplication: 60
# exponential power: 50625
# division: 3.75
# floor division: 3
# modulo divison: 3

# %%
length=5
breadth=8
area=length*breadth
perimeter=2*(length+breadth)
print("area:",area)
print("perimeter:",perimeter)
# Out:
# area: 40
# perimeter: 26
